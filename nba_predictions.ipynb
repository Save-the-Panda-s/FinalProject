# %% [markdown]
# **import dependencies**

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
import pandas as pd

# %% [markdown]
# **import csv file**

# %%
nba_stats_df = pd.read_csv('Resources/nbastats copy.csv', skiprows = 1)

nba_stats_df.head()
# Out:
#    RANK                 FULL NAME TEAM  POS    AGE  GP   MPG  \
# 0   NaN          Precious Achiuwa  Tor    F  22.66   6  27.8
# 1   NaN              Steven Adams  Mem    C  28.82   7  16.2
# 2   NaN               Bam Adebayo  Mia  C-F  24.83  11  32.1
# 3   NaN  Nickeil Alexander-Walker  Uta    G  23.70   1   4.7
# 4   NaN             Grayson Allen  Mil    G  26.60  12  25.4
#
#    MIN%Minutes PercentagePercentage of team minutes used by a player while he was on the floor  \
# 0                                               57.8
# 1                                               33.8
# 2                                               66.8
# 3                                                9.8
# 4                                               53.0
#
#    USG%Usage RateUsage rate, a.k.a., usage percentage is an estimate of the percentage of team plays used by a player while he was on the floor  \
# 0                                               18.2
# 1                                               10.8
# 2                                               18.8
# 3                                               24.4
# 4                                               13.6
#
#    TO%Turnover RateA metric that estimates the number of turnovers a player commits per 100 possessions  \
# 0                                               13.8
# 1                                               13.4
# 2                                               17.6
# 3                                                0.0
# 4                                                9.4
#
#    ...  RPGReboundsRebounds per game.  \
# 0  ...                            4.8
# 1  ...                            6.4
# 2  ...                            7.7
# 3  ...                            1.0
# 4  ...                            2.9
#
#    TRB%Total Rebound PercentageTotal rebound percentage is estimated percentage of available rebounds grabbed by the player while the player is on the court.  \
# 0                                               10.7
# 1                                               20.9
# 2                                               14.6
# 3                                               12.4
# 4                                                5.9
#
#    APGAssistsAssists per game.  \
# 0                          1.0
# 1                          2.1
# 2                          2.7
# 3                          1.0
# 4                          1.3
#
#    AST%Assist PercentageAssist percentage is an estimated percentage of teammate field goals a player assisted while the player is on the court  \
# 0                                                5.7
# 1                                               17.6
# 2                                               13.0
# 3                                               70.1
# 4                                                7.2
#
#    SPGStealsSteals per game.  BPGBlocksBlocks per game.  \
# 0                       0.17                       0.83
# 1                       0.14                       0.14
# 2                       1.18                       0.64
# 3                       1.00                       0.00
# 4                       0.67                       0.33
#
#    TOPGTurnoversTurnovers per game.  \
# 0                              1.50
# 1                              0.57
# 2                              2.36
# 3                              0.00
# 4                              0.75
#
#    VIVersatility IndexVersatility index is a metric that measures a player’s ability to produce in points, assists, and rebounds. The average player will score around a five on the index, while top players score above 10  \
# 0                                                5.3
# 1                                                8.8
# 2                                                8.4
# 3                                               14.6
# 4                                                5.0
#
#    ORTGOffensive RatingIndividual offensive rating is the number of points produced by a player per 100 total individual possessions.  \
# 0                                              103.3
# 1                                              120.1
# 2                                              120.5
# 3                                              214.3
# 4                                              112.0
#
#    DRTGDefensive RatingIndividual defensive rating estimates how many points the player allowed per 100 possessions he individually faced while staying on the court.
# 0                                              107.9
# 1                                              100.4
# 2                                               99.5
# 3                                              100.3
# 4                                              107.6
#
# [5 rows x 29 columns]

# %% [markdown]
# **clean data**

# %%
nba_stats_df = nba_stats_df.drop(columns = ['RANK'])
nba_stats_df.head()
# Out:
#                   FULL NAME TEAM  POS    AGE  GP   MPG  \
# 0          Precious Achiuwa  Tor    F  22.66   6  27.8
# 1              Steven Adams  Mem    C  28.82   7  16.2
# 2               Bam Adebayo  Mia  C-F  24.83  11  32.1
# 3  Nickeil Alexander-Walker  Uta    G  23.70   1   4.7
# 4             Grayson Allen  Mil    G  26.60  12  25.4
#
#    MIN%Minutes PercentagePercentage of team minutes used by a player while he was on the floor  \
# 0                                               57.8
# 1                                               33.8
# 2                                               66.8
# 3                                                9.8
# 4                                               53.0
#
#    USG%Usage RateUsage rate, a.k.a., usage percentage is an estimate of the percentage of team plays used by a player while he was on the floor  \
# 0                                               18.2
# 1                                               10.8
# 2                                               18.8
# 3                                               24.4
# 4                                               13.6
#
#    TO%Turnover RateA metric that estimates the number of turnovers a player commits per 100 possessions  \
# 0                                               13.8
# 1                                               13.4
# 2                                               17.6
# 3                                                0.0
# 4                                                9.4
#
#    FTA  ...  RPGReboundsRebounds per game.  \
# 0   10  ...                            4.8
# 1   11  ...                            6.4
# 2   59  ...                            7.7
# 3    1  ...                            1.0
# 4   11  ...                            2.9
#
#    TRB%Total Rebound PercentageTotal rebound percentage is estimated percentage of available rebounds grabbed by the player while the player is on the court.  \
# 0                                               10.7
# 1                                               20.9
# 2                                               14.6
# 3                                               12.4
# 4                                                5.9
#
#    APGAssistsAssists per game.  \
# 0                          1.0
# 1                          2.1
# 2                          2.7
# 3                          1.0
# 4                          1.3
#
#    AST%Assist PercentageAssist percentage is an estimated percentage of teammate field goals a player assisted while the player is on the court  \
# 0                                                5.7
# 1                                               17.6
# 2                                               13.0
# 3                                               70.1
# 4                                                7.2
#
#    SPGStealsSteals per game.  BPGBlocksBlocks per game.  \
# 0                       0.17                       0.83
# 1                       0.14                       0.14
# 2                       1.18                       0.64
# 3                       1.00                       0.00
# 4                       0.67                       0.33
#
#    TOPGTurnoversTurnovers per game.  \
# 0                              1.50
# 1                              0.57
# 2                              2.36
# 3                              0.00
# 4                              0.75
#
#    VIVersatility IndexVersatility index is a metric that measures a player’s ability to produce in points, assists, and rebounds. The average player will score around a five on the index, while top players score above 10  \
# 0                                                5.3
# 1                                                8.8
# 2                                                8.4
# 3                                               14.6
# 4                                                5.0
#
#    ORTGOffensive RatingIndividual offensive rating is the number of points produced by a player per 100 total individual possessions.  \
# 0                                              103.3
# 1                                              120.1
# 2                                              120.5
# 3                                              214.3
# 4                                              112.0
#
#    DRTGDefensive RatingIndividual defensive rating estimates how many points the player allowed per 100 possessions he individually faced while staying on the court.
# 0                                              107.9
# 1                                              100.4
# 2                                               99.5
# 3                                              100.3
# 4                                              107.6
#
# [5 rows x 28 columns]

# %%
nba_stats_df = nba_stats_df.rename(columns = {'MIN%Minutes PercentagePercentage of team minutes used by a player while he was on the floor': '%MIN', 
                                              'USG%Usage RateUsage rate, a.k.a., usage percentage is an estimate of the percentage of team plays used by a player while he was on the floor': '%USG', 
                                              'TO%Turnover RateA metric that estimates the number of turnovers a player commits per 100 possessions': '%TO',
                                             'RPGReboundsRebounds per game.': 'RPG',
                                             'APGAssistsAssists per game.': 'APG',
                                             'AST%Assist PercentageAssist percentage is an estimated percentage of teammate field goals a player assisted while the player is on the court': '%AST',
                                             'SPGStealsSteals per game.': 'SPG',
                                             'BPGBlocksBlocks per game.': 'BPG',
                                             'TOPGTurnoversTurnovers per game.': 'TOPG',
                                             'VIVersatility IndexVersatility index is a metric that measures a player’s ability to produce in points, assists, and rebounds. The average player will score around a five on the index, while top players score above 10': 'VersatilityIndex',
                                             'ORTGOffensive RatingIndividual offensive rating is the number of points produced by a player per 100 total individual possessions': 'Offensive Rating',
                                             'DRTGDefensive RatingIndividual defensive rating estimates how many points the player allowed per 100 possessions he individually faced while staying on the court.': 'Defensive Rating'})

nba_stats_df.head()
# Out:
#                   FULL NAME TEAM  POS    AGE  GP   MPG  %MIN  %USG   %TO  FTA  \
# 0          Precious Achiuwa  Tor    F  22.66   6  27.8  57.8  18.2  13.8   10
# 1              Steven Adams  Mem    C  28.82   7  16.2  33.8  10.8  13.4   11
# 2               Bam Adebayo  Mia  C-F  24.83  11  32.1  66.8  18.8  17.6   59
# 3  Nickeil Alexander-Walker  Uta    G  23.70   1   4.7   9.8  24.4   0.0    1
# 4             Grayson Allen  Mil    G  26.60  12  25.4  53.0  13.6   9.4   11
#
#    ...  RPG  \
# 0  ...  4.8
# 1  ...  6.4
# 2  ...  7.7
# 3  ...  1.0
# 4  ...  2.9
#
#    TRB%Total Rebound PercentageTotal rebound percentage is estimated percentage of available rebounds grabbed by the player while the player is on the court.  \
# 0                                               10.7
# 1                                               20.9
# 2                                               14.6
# 3                                               12.4
# 4                                                5.9
#
#    APG  %AST   SPG   BPG  TOPG  VersatilityIndex  \
# 0  1.0   5.7  0.17  0.83  1.50               5.3
# 1  2.1  17.6  0.14  0.14  0.57               8.8
# 2  2.7  13.0  1.18  0.64  2.36               8.4
# 3  1.0  70.1  1.00  0.00  0.00              14.6
# 4  1.3   7.2  0.67  0.33  0.75               5.0
#
#    ORTGOffensive RatingIndividual offensive rating is the number of points produced by a player per 100 total individual possessions.  \
# 0                                              103.3
# 1                                              120.1
# 2                                              120.5
# 3                                              214.3
# 4                                              112.0
#
#    Defensive Rating
# 0             107.9
# 1             100.4
# 2              99.5
# 3             100.3
# 4             107.6
#
# [5 rows x 28 columns]

# %%
nba_stats_df = nba_stats_df.rename( 
    columns =  { 
    'TRB%Total Rebound PercentageTotal rebound percentage is estimated percentage of available rebounds grabbed by the player while the player is on the court.' : '%TRB',
    'ORTGOffensive RatingIndividual offensive rating is the number of points produced by a player per 100 total individual possessions.' : 'Offensive Rating',
    'eFG%Effective Shooting PercentageWith eFG%, three-point shots made are worth 50% more than two-point shots made. eFG% Formula=(FGM+ (0.5 x 3PM))/FGA' : '%eFG',
    'PPGPointsPoints per game.' : 'PPG',
    'TS%True Shooting PercentageTrue shooting percentage is a measure of shooting efficiency that takes into account field goals, 3-point field goals, and free throws.': '%TS'
})

nba_stats_df.head()
# Out:
#                   FULL NAME TEAM  POS    AGE  GP   MPG  %MIN  %USG   %TO  FTA  \
# 0          Precious Achiuwa  Tor    F  22.66   6  27.8  57.8  18.2  13.8   10
# 1              Steven Adams  Mem    C  28.82   7  16.2  33.8  10.8  13.4   11
# 2               Bam Adebayo  Mia  C-F  24.83  11  32.1  66.8  18.8  17.6   59
# 3  Nickeil Alexander-Walker  Uta    G  23.70   1   4.7   9.8  24.4   0.0    1
# 4             Grayson Allen  Mil    G  26.60  12  25.4  53.0  13.6   9.4   11
#
#    ...  RPG  %TRB  APG  %AST   SPG   BPG  TOPG  VersatilityIndex  \
# 0  ...  4.8  10.7  1.0   5.7  0.17  0.83  1.50               5.3
# 1  ...  6.4  20.9  2.1  17.6  0.14  0.14  0.57               8.8
# 2  ...  7.7  14.6  2.7  13.0  1.18  0.64  2.36               8.4
# 3  ...  1.0  12.4  1.0  70.1  1.00  0.00  0.00              14.6
# 4  ...  2.9   5.9  1.3   7.2  0.67  0.33  0.75               5.0
#
#    Offensive Rating  Defensive Rating
# 0             103.3             107.9
# 1             120.1             100.4
# 2             120.5              99.5
# 3             214.3             100.3
# 4             112.0             107.6
#
# [5 rows x 28 columns]

# %%
nba_stats_df.columns
# Out:
# Index(['FULL NAME', 'TEAM', 'POS', 'AGE', 'GP', 'MPG', '%MIN', '%USG', '%TO',
#        'FTA', 'FT%', '2PA', '2P%', '3PA', '3P%', '%eFG', '%TS', 'PPG', 'RPG',
#        '%TRB', 'APG', '%AST', 'SPG', 'BPG', 'TOPG', 'VersatilityIndex',
#        'Offensive Rating', 'Defensive Rating'],
#       dtype='object')

# %%
nba_stats_df.dtypes
# Out:
# FULL NAME            object
# TEAM                 object
# POS                  object
# AGE                 float64
# GP                    int64
# MPG                 float64
# %MIN                float64
# %USG                float64
# %TO                 float64
# FTA                   int64
# FT%                 float64
# 2PA                   int64
# 2P%                 float64
# 3PA                   int64
# 3P%                 float64
# %eFG                float64
# %TS                 float64
# PPG                 float64
# RPG                 float64
# %TRB                float64
# APG                 float64
# %AST                float64
# SPG                 float64
# BPG                 float64
# TOPG                float64
# VersatilityIndex    float64
# Offensive Rating    float64
# Defensive Rating    float64
# dtype: object

# %% [markdown]
# **separate features from the target**

# %%
y = 
X =

# %% [markdown]
# **split data into training and testing**

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 1)

# %% [markdown]
# **stadardize the features**

# %%
scaler = StandardScaler()
X_scaler = scaler.fit(X_train)

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# **logistic regression model**

# %%
# instantiate logistic regression model
model = LogisticRegression(random_state = 1)

# fit and train the model
model.fit(X_train, y_train)

# make predictions
pred = model.predict(X_test_scaled)

# %%
# accuracy score
print(accuracy_score(y_test, pred))

# %%
# classification report
print(classification_report(y_test, pred))
