# %%
import pandas as pd
from basketball_reference_web_scraper import client

# %%
player_json = client.players_advanced_season_totals(season_end_year=2022)

# %%
df = pd.DataFrame(player_json)

# %%
df.columns
# Out:
# Index(['slug', 'name', 'positions', 'age', 'team', 'games_played',
#        'minutes_played', 'player_efficiency_rating',
#        'true_shooting_percentage', 'three_point_attempt_rate',
#        'free_throw_attempt_rate', 'offensive_rebound_percentage',
#        'defensive_rebound_percentage', 'total_rebound_percentage',
#        'assist_percentage', 'steal_percentage', 'block_percentage',
#        'turnover_percentage', 'usage_percentage', 'offensive_win_shares',
#        'defensive_win_shares', 'win_shares', 'win_shares_per_48_minutes',
#        'offensive_box_plus_minus', 'defensive_box_plus_minus',
#        'box_plus_minus', 'value_over_replacement_player',
#        'is_combined_totals'],
#       dtype='object')

# %%
df
# Out:
#           slug               name                 positions  age  \
# 0    achiupr01   Precious Achiuwa         [Position.CENTER]   22
# 1    adamsst01       Steven Adams         [Position.CENTER]   28
# 2    adebaba01        Bam Adebayo         [Position.CENTER]   24
# 3    aldamsa01       Santi Aldama  [Position.POWER_FORWARD]   21
# 4    aldrila01  LaMarcus Aldridge         [Position.CENTER]   36
# ..         ...                ...                       ...  ...
# 710  youngth01     Thaddeus Young  [Position.POWER_FORWARD]   33
# 711  youngtr01         Trae Young    [Position.POINT_GUARD]   23
# 712  yurtsom01     Omer Yurtseven         [Position.CENTER]   23
# 713  zelleco01        Cody Zeller         [Position.CENTER]   29
# 714  zubaciv01        Ivica Zubac         [Position.CENTER]   24
#
#                             team  games_played  minutes_played  \
# 0           Team.TORONTO_RAPTORS            73            1725
# ...

# %%
team_scores_list = []
for x in range(1,2):
    for y in range(1, 2):
        team_scores = client.team_box_scores(day=y, month=x, year=2022)
        team_scores_list.extend(team_scores)

# %%
team_scores_list
# Out:
# [{'team': <Team.LOS_ANGELES_CLIPPERS: 'LOS ANGELES CLIPPERS'>,
#   'outcome': <Outcome.WIN: 'WIN'>,
#   'minutes_played': 240,
#   'made_field_goals': 42,
#   'attempted_field_goals': 86,
#   'made_three_point_field_goals': 14,
#   'attempted_three_point_field_goals': 36,
#   'made_free_throws': 22,
#   'attempted_free_throws': 31,
#   'offensive_rebounds': 7,
#   'defensive_rebounds': 33,
#   'assists': 23,
#   'steals': 7,
#   'blocks': 6,
#   'turnovers': 10,
#   'personal_fouls': 19,
#   'points': 120},
#  {'team': <Team.BROOKLYN_NETS: 'BROOKLYN NETS'>,
#   'outcome': <Outcome.LOSS: 'LOSS'>,
#   'minutes_played': 240,
#   'made_field_goals': 42,
#   'attempted_field_goals': 97,
#   'made_three_point_field_goals': 11,
#   'attempted_three_point_field_goals': 33,
#   'made_free_throws': 21,
#   'attempted_free_throws': 25,
#   'offensive_rebounds': 17,
#   'defensive_rebounds': 40,
#   'assists': 26,
#   'steals': 9,
#   'blocks': 2,
#   'turnovers': 14,
#   'personal_fouls': 20,
# ...

# %%
df2 = pd.DataFrame(team_scores_list)
df2
# Out:
#                           team       outcome  minutes_played  \
# 0    Team.LOS_ANGELES_CLIPPERS   Outcome.WIN             240
# 1           Team.BROOKLYN_NETS  Outcome.LOSS             240
# 2       Team.SAN_ANTONIO_SPURS  Outcome.LOSS             265
# 3         Team.DETROIT_PISTONS   Outcome.WIN             265
# 4          Team.DENVER_NUGGETS   Outcome.WIN             240
# 5         Team.HOUSTON_ROCKETS  Outcome.LOSS             240
# 6    Team.NEW_ORLEANS_PELICANS  Outcome.LOSS             240
# 7         Team.MILWAUKEE_BUCKS   Outcome.WIN             240
# 8   Team.GOLDEN_STATE_WARRIORS   Outcome.WIN             240
# 9               Team.UTAH_JAZZ  Outcome.LOSS             240
# 10          Team.CHICAGO_BULLS   Outcome.WIN             240
# 11     Team.WASHINGTON_WIZARDS  Outcome.LOSS             240
#
#     made_field_goals  attempted_field_goals  made_three_point_field_goals  \
# 0                 42                     86                            14
# ...

# %%
team_scores
# Out:
# [{'team': <Team.LOS_ANGELES_CLIPPERS: 'LOS ANGELES CLIPPERS'>,
#   'outcome': <Outcome.WIN: 'WIN'>,
#   'minutes_played': 240,
#   'made_field_goals': 42,
#   'attempted_field_goals': 86,
#   'made_three_point_field_goals': 14,
#   'attempted_three_point_field_goals': 36,
#   'made_free_throws': 22,
#   'attempted_free_throws': 31,
#   'offensive_rebounds': 7,
#   'defensive_rebounds': 33,
#   'assists': 23,
#   'steals': 7,
#   'blocks': 6,
#   'turnovers': 10,
#   'personal_fouls': 19,
#   'points': 120},
#  {'team': <Team.BROOKLYN_NETS: 'BROOKLYN NETS'>,
#   'outcome': <Outcome.LOSS: 'LOSS'>,
#   'minutes_played': 240,
#   'made_field_goals': 42,
#   'attempted_field_goals': 97,
#   'made_three_point_field_goals': 11,
#   'attempted_three_point_field_goals': 33,
#   'made_free_throws': 21,
#   'attempted_free_throws': 25,
#   'offensive_rebounds': 17,
#   'defensive_rebounds': 40,
#   'assists': 26,
#   'steals': 9,
#   'blocks': 2,
#   'turnovers': 14,
#   'personal_fouls': 20,
# ...
